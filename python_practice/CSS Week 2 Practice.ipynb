# %% [markdown]
# # Practice Week 2
#
# ## NumPy and Pandas
#
# ### These labs provide an opportunity for you to practice your new NumPy and Pandas knowledge. There is a lot of flexibility in how to answer these questions so they are not autograded. Call over an insutrctor or TA for help or to review your answers.

# %% [markdown]
# ## Step 1: Import necessary packages

# %%
## import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Step 2: Load in the dataset

# %%
# Read in data from source
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        NaN        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      316.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396      324.0        110.0                3.0  3.5  3.5  9.04
# 396         397      325.0        107.0                3.0  3.0  3.5  9.11
# 397         398      330.0        116.0                4.0  5.0  4.5  9.45
# 398         399      312.0        103.0                3.0  3.5  4.0  8.78
# 399         400      333.0        117.0                4.0  5.0  4.0  9.66
#
#      Research
# 0           1
# 1           1
# 2           1
# ...

# %% [markdown]
# ## Step 3: Create a variable you can work with (so you don't overwrite your original)

# %%
# Out:
# Serial No.           400
# GRE Score            398
# TOEFL Score          398
# University Rating    399
# SOP                  400
# LOR                  399
# CGPA                 399
# Research             400
# dtype: int64

# %% [markdown]
# ## Step 4: What does your data look like?
#
# ### First, clean up any NaNs.

# %%
## check where there are NaNs and count

## drop the NaNs

# %% [markdown]
# ### How many observations are there now?

# %%
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      316.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# 5             6      330.0        115.0                5.0  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396      324.0        110.0                3.0  3.5  3.5  9.04
# 396         397      325.0        107.0                3.0  3.0  3.5  9.11
# 397         398      330.0        116.0                4.0  5.0  4.5  9.45
# 398         399      312.0        103.0                3.0  3.5  4.0  8.78
# 399         400      333.0        117.0                4.0  5.0  4.0  9.66
#
#      Research
# 1           1
# 2           1
# 3           1
# ...

# %% [markdown]
# ### Summarize the data in a summary table.
#
# #### Hint: look at some of the pandas attributes to see if there's one that will do summary statistics.

# %%
# Out:
#        Serial No.  GRE Score  TOEFL Score  University Rating         SOP  \
# count  393.000000  393.00000   393.000000         393.000000  393.000000
# mean   202.040712  316.73028   107.356234           3.086514    3.399491
# std    115.205178   11.50304     6.086562           1.150708    1.010506
# min      2.000000  290.00000    92.000000           1.000000    1.000000
# 25%    103.000000  308.00000   103.000000           2.000000    2.500000
# 50%    202.000000  317.00000   107.000000           3.000000    3.500000
# 75%    301.000000  325.00000   112.000000           4.000000    4.000000
# max    400.000000  340.00000   120.000000           5.000000    5.000000
#
#               LOR        CGPA    Research
# count  393.000000  393.000000  393.000000
# mean     3.451654    8.598677    0.541985
# std      0.902210    0.596524    0.498869
# min      1.000000    6.800000    0.000000
# 25%      3.000000    8.170000    0.000000
# 50%      3.500000    8.620000    1.000000
# ...

# %% [markdown]
# ### What's the range for some of these categories? What's the range of Research Experience vs. GRE Score? Why are they different? Can you define a function that tells you what the range of a given column is?
#
# #### Hint: you can.

# %%
## something

# %% [markdown]
# ## Step 5: Transform your data for visualization.

# %% [markdown]
# ### Transform a single column of the dataset.Define a function that implements some of the math operations of NumPy on your data.
# #### Perhaps it's helpful to change the decimal places on a given column, or multiply the column by another number. You decide!

# %%
# Out:
# /tmp/ipykernel_129/1742858888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Admit Percentage'] = df['Chance of Admit'] * 100
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3      316.0        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# 5             6      330.0        115.0                5.0  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# ...

# %% [markdown]
# ### Create a histogram of the data you converted.

# %%
### histogram

# %% [markdown]
# ## Step 6: Get the data you need via subsetting.

# %% [markdown]
# ### Create a new df with only the data for GRE Score and Research.
# #### Hint: use [] or pandas attributes.

# %%
# Out:
#      GRE Score  Research
# 1        324.0         1
# 2        316.0         1
# 3        322.0         1
# 4        314.0         0
# 5        330.0         1
# ..         ...       ...
# 395      324.0         1
# 396      325.0         1
# 397      330.0         1
# 398      312.0         0
# 399      333.0         1
#
# [392 rows x 2 columns]

# %% [markdown]
# ## Step 7: Start plotting!

# %% [markdown]
# ### Plot a histogram of the GRE data.

# %%
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Plot a boxplot of the GRE data.

# %%
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# ### Plot a histogram of the Research data.

# %% [markdown]
# ### How'd that go?

# %% [markdown]
# #### It probably doesn't look great for Research because Research is just a binary 1 or 0.
# #### Plotting requires thinking about how the data should be represented, and that starts with slicing and transforming the data appropriately, then then choosing the right graph.

# %% [markdown]
# ### Try making a graph that represents the Research data well.
#
# #### Hint: You might need to change the shape or the data or pivot to get the categories you need.

# %% [markdown]
# ### Now you can try plotting the Chance of Admit data, but...

# %% [markdown]
# ## Step 8: Oh no you forgot some data.

# %% [markdown]
# ### Load in the 'chance' dataset and merge it with the admission_predict dataset.
#
# ### Beware the NaNs.
#
# ##### Hint: You might need to complete some steps again (1-5).

# %% [markdown]
# ### Plot the histogram for the Chance of Admit data and show the summary table for the newly complete dataset.

# %% [markdown]
# ## Bonus Round: Predict Chance of Admit based on GRE Scores
# ### Use the OLS tutorial to create a model summary that shows how we might predict the effect of GRE Scores on the chance of being admitted.

# %%
# copy model tutorial from yesterday
