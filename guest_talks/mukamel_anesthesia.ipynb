# %%
import pandas as pd, numpy as np
from sklearn.linear_model import Ridge,Lasso

from sklearn import linear_model
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
import sklearn
from statsmodels.regression.linear_model import OLS

# %%
data=pd.read_csv('https://urldefense.com/v3/__https://www.dropbox.com/s/mud801ie723v8oq/anesthesia.csv?dl=1__;!!Mih3wA!HYByRm7XMLY6k-K8yGAhhIDZsfJ5r5g8CSnPK6QKeUAK86Py91M6LVY_J-qzmTkEGyUQE-r9gZkQevRgRAg$ ')

# %%
plt.plot(data['Time'], data['BehaviorResponse'], 'r')
plt.xlabel('Time (s)')
plt.ylabel('Probability of response')
# Out:
# Text(0, 0.5, 'Probability of response')

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.iloc[:,1:-1].T, 
            cbar_kws={'label':'log(EEG power)', 'shrink':0.5},
            cmap='jet',
           )
plt.gca().invert_yaxis()
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
# Out:
# Text(113.09375, 0.5, 'Frequency (Hz)')

# %%
# mdl = OLS.
mdl_outputs = pd.DataFrame()
for frequency in data.columns[1:-1]:
    mdl = OLS(data['BehaviorResponse'], data[frequency]).fit()
    mdl_outputs.loc[frequency,'R-squared'] = mdl.rsquared

# %%
# Find the best new frequency, add it to the model

# %%
# Compare the performance of models as a function of the number of frequencies used

# %%
# Now repeat this process using cross-validation
train_data,test_data = sklearn.model_selection.train_test_split(data)
